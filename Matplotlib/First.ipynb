# %% [markdown]
# # Import matplotlib librar

# %%
import matplotlib.pyplot as plt

# %%
a = [1,2,3,4,5]
b = [10,15,30,40,50]

clr = ["r",'y',"g",'g','o']

plt.bar(a,b,clr)
plt.show
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anacondaML\Lib\site-packages\matplotlib\axes\_axes.py:2316, in Axes._convert_dx(dx, x0, xconv, convert)
#    2315     delist = True
# -> 2316 dx = [convert(x0 + ddx) - x for ddx in dx]
#    2317 if delist:
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~\anacondaML\Lib\site-packages\matplotlib\axis.py:1813, in Axis.convert_units(self, x)
#    1812 try:
# -> 1813     ret = self.converter.convert(x, self.units, self)
#    1814 except Exception as e:
#
# File ~\anacondaML\Lib\site-packages\matplotlib\category.py:49, in StrCategoryConverter.convert(value, unit, axis)
#      48 if unit is None:
# ---> 49     raise ValueError(
# ...
