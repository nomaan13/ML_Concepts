# %%
# import matplotlib
import matplotlib.pyplot as plt


a = ["Python","Java","C++","Javascript","Kotlin",]
b = [91,88,70,80,50]

plt.plot(a,b, marker ='H')
plt.show()

# %%
x = [2,4,6,8,5]
plt.plot(x ,'o:r')
plt.show()

# %%
q=[2,4,6,8,10,12,14]
p=[10,40,30,50,20,70,25]

plt.xlabel("Age")
plt.ylabel("Weight")

plt.title("Ratio")

plt.plot(q,p,'o:r',ms=14,mec="Green" ,linestyle="dashed")
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12552\3158465963.py:9: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o:r" (-> linestyle=':'). The keyword argument will take precedence.
#   plt.plot(q,p,'o:r',ms=14,mec="Green" ,linestyle="dashed")
